# %% [markdown]
# # This is Jeopardy!

# %%
# !pwd
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/Data_Science/01_Jeopardy'
# Out:
# /content/drive/MyDrive/Data_Science/01_Jeopardy

# %% [markdown]
# #### Project Goals

# %% [markdown]
# You will work to write several functions that investigate a dataset of _Jeopardy!_ questions and answers. Filter the dataset for topics that you're interested in, compute the average difficulty of those questions, and train to become the next Jeopardy champion!

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# In order to complete this project, you should have completed the Pandas lessons in the <a href="https://www.codecademy.com/learn/paths/analyze-data-with-python">Analyze Data with Python Skill Path</a>. You can also find those lessons in the <a href="https://www.codecademy.com/learn/data-processing-pandas">Data Analysis with Pandas course</a> or the <a href="https://www.codecademy.com/learn/paths/data-science/">Data Scientist Career Path</a>.
#
# Finally, the <a href="https://www.codecademy.com/learn/practical-data-cleaning">Practical Data Cleaning</a> course may also be helpful.

# %% [markdown]
# ## Project Requirements

# %% [markdown]
# 1. We've provided a csv file containing data about the game show _Jeopardy!_ in a file named `jeopardy.csv`. Load the data into a DataFrame and investigate its contents. Try to print out specific columns.
#
#    Note that in order to make this project as "real-world" as possible, we haven't modified the data at all - we're giving it to you exactly how we found it. As a result, this data isn't as "clean" as the datasets you normally find on Codecademy. More specifically, there's something odd about the column names. After you figure out the problem with the column names, you may want to rename them to make your life easier for the rest of the project.
#
#    In order to display the full contents of a column, we've added this line of code for you:
#
#    ```py
#    pd.set_option('display.max_colwidth', None)
#    ```

# %%
import pandas as pd
import numpy as np
import datetime
pd.set_option('display.max_colwidth', None)

# %%
data_df = pd.read_csv('jeopardy.csv')
data_df.columns
data_df.head()
# Out:
#    Show Number    Air Date      Round                         Category  Value  \
# 0         4680  2004-12-31  Jeopardy!                          HISTORY   $200
# 1         4680  2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES   $200
# 2         4680  2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...   $200
# 3         4680  2004-12-31  Jeopardy!                 THE COMPANY LINE   $200
# 4         4680  2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES   $200
#
#                                                                                                       Question  \
# 0             For the last 8 years of his life, Galileo was under house arrest for espousing this man's theory
# 1  No. 2: 1912 Olympian; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves
# 2                     The city of Yuma in this state has a record average of 4,055 hours of sunshine each year
# ...

# %% [markdown]
# *The problem was that the tite of some columns presented a space at the beginning of the name.*

# %%
data_df.columns = [column_name.strip() for column_name  in data_df.columns] # Solving the issue with the extra empty spaces

# %% [markdown]
# 2. Write a function that filters the dataset for questions that contains all of the words in a list of words. For example, when the list `["King", "England"]` was passed to our function, the function returned a DataFrame of 49 rows. Every row had the strings `"King"` and `"England"` somewhere in its `" Question"`.
#
#    Test your function by printing out the column containing the question of each row of the dataset.

# %%
def return_df_with_certain_words_in_question(words_to_look):
  """ 
  Function that returns a dataframe ehre the column Question has a word passed as parameters

  Arguments:
    words_to_look -- List with the words to look

  Returns:
    df_result --  df with the rows containing any of the words passed in the list
  """
  df_result = pd.DataFrame()
  for index, row in data_df.iterrows():
    if any(word in row['Question'].split() for word in words_to_look):
      df_result = pd.concat([df_result, row], axis = 1)
  df_result = df_result.T
  return df_result

# %%
trial = return_df_with_certain_words_in_question(['King', 'England'])
trial
# Out:
#        Show Number    Air Date             Round            Category  Value  \
# 116           5957  2010-07-06   Final Jeopardy!      HISTORIC WOMEN   None
# 296           4931  2006-02-06   Final Jeopardy!        FAMOUS SHIPS   None
# 386           2825  1996-12-06         Jeopardy!       ANNUAL EVENTS   $500
# 621           4107  2002-06-11         Jeopardy!  "BLACK" OR "WHITE"  $1000
# 811           4335  2003-06-06  Double Jeopardy!         "S"-OTERICA   $400
# ...            ...         ...               ...                 ...    ...
# 216445        3644  2000-06-08   Final Jeopardy!           THE BIBLE   None
# 216550        3038  1997-11-12  Double Jeopardy!           COLONISTS   $600
# 216752        5070  2006-09-29         Jeopardy!         SIGNING OFF   $200
# 216777        5070  2006-09-29  Double Jeopardy!     ANCIENT HISTORY   $400
# 216789        5070  2006-09-29  Double Jeopardy!     ANCIENT HISTORY  $1200
#
# ...

# %% [markdown]
# 3. Test your original function with a few different sets of words to try to find some ways your function breaks. Edit your function so it is more robust.
#
#    For example, think about capitalization. We probably want to find questions that contain the word `"King"` or `"king"`.
#
#    You may also want to check to make sure you don't find rows that contain substrings of your given words. For example, our function found a question that didn't contain the word `"king"`, however it did contain the word `"viking"` &mdash; it found the `"king"` inside `"viking"`. Note that this also comes with some drawbacks &mdash; you would no longer find questions that contained words like `"England's"`.

# %%
def return_df_with_certain_words_in_question(words_to_look):
  """ 
  Function that returns a dataframe where the column Question has a word passed as parameters. It has been considered caipatl letters

  Arguments:
    words_to_look -- List with the words to look

  Returns:
    df_result --  df with the rows containing any of the words passed in the list
  """
  df_result = pd.DataFrame()
  for index, row in data_df.iterrows():
    if any(word.lower() in row['Question'].lower().split() for word in words_to_look):
      df_result = pd.concat([df_result, row], axis = 1)
  df_result = df_result.T
  return df_result

# %%
trial2 = return_df_with_certain_words_in_question(['KING', 'ENGLAND'])

# %% [markdown]
# 4. We may want to eventually compute aggregate statistics, like `.mean()` on the `" Value"` column. But right now, the values in that column are strings. Convert the`" Value"` column to floats. If you'd like to, you can create a new column with float values.
#
#    Now that you can filter the dataset of question, use your new column that contains the float values of each question to find the "difficulty" of certain topics. For example, what is the average value of questions that contain the word `"King"`?
#
#    Make sure to use the dataset that contains the float values as the dataset you use in your filtering function.

# %%
data_df.head()
# Out:
#    Show Number    Air Date      Round                         Category Value  \
# 0         4680  2004-12-31  Jeopardy!                          HISTORY  $200
# 1         4680  2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES  $200
# 2         4680  2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...  $200
# 3         4680  2004-12-31  Jeopardy!                 THE COMPANY LINE  $200
# 4         4680  2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES  $200
#
#                                                                                                       Question  \
# 0             For the last 8 years of his life, Galileo was under house arrest for espousing this man's theory
# 1  No. 2: 1912 Olympian; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves
# 2                     The city of Yuma in this state has a record average of 4,055 hours of sunshine each year
# ...

# %%
data_df.columns
# Out:
# Index(['Show Number', 'Air Date', 'Round', 'Category', 'Value', 'Question',
#        'Answer'],
#       dtype='object')

# %%
data_df['Value_float'] = pd.to_numeric(data_df['Value'], errors='coerce')

# %%
data_df
# Out:
#         Show Number    Air Date             Round  \
# 0              4680  2004-12-31         Jeopardy!
# 1              4680  2004-12-31         Jeopardy!
# 2              4680  2004-12-31         Jeopardy!
# 3              4680  2004-12-31         Jeopardy!
# 4              4680  2004-12-31         Jeopardy!
# ...             ...         ...               ...
# 216925         4999  2006-05-11  Double Jeopardy!
# 216926         4999  2006-05-11  Double Jeopardy!
# 216927         4999  2006-05-11  Double Jeopardy!
# 216928         4999  2006-05-11  Double Jeopardy!
# 216929         4999  2006-05-11   Final Jeopardy!
#
#                                Category  Value  \
# 0                               HISTORY   $200
# 1       ESPN's TOP 10 ALL-TIME ATHLETES   $200
# 2           EVERYBODY TALKS ABOUT IT...   $200
# 3                      THE COMPANY LINE   $200
# 4                   EPITAPHS & TRIBUTES   $200
# ...                                 ...    ...
# ...

# %%
data_df['Value_float'] = data_df.apply(lambda row: float(row['Value'].replace('$', '').replace(',','').replace('None','-999')), axis = 1)
data_df.Value_float.replace(-999, np.nan, inplace = True)
data_df
# Out:
#         Show Number    Air Date             Round  \
# 0              4680  2004-12-31         Jeopardy!
# 1              4680  2004-12-31         Jeopardy!
# 2              4680  2004-12-31         Jeopardy!
# 3              4680  2004-12-31         Jeopardy!
# 4              4680  2004-12-31         Jeopardy!
# ...             ...         ...               ...
# 216925         4999  2006-05-11  Double Jeopardy!
# 216926         4999  2006-05-11  Double Jeopardy!
# 216927         4999  2006-05-11  Double Jeopardy!
# 216928         4999  2006-05-11  Double Jeopardy!
# 216929         4999  2006-05-11   Final Jeopardy!
#
#                                Category  Value  \
# 0                               HISTORY   $200
# 1       ESPN's TOP 10 ALL-TIME ATHLETES   $200
# 2           EVERYBODY TALKS ABOUT IT...   $200
# 3                      THE COMPANY LINE   $200
# 4                   EPITAPHS & TRIBUTES   $200
# ...                                 ...    ...
# ...

# %% [markdown]
# 5. Write a function that returns the count of unique answers to all of the questions in a dataset. For example, after filtering the entire dataset to only questions containing the word `"King"`, we could then find all of the unique answers to those questions. The answer "Henry VIII" appeared 55 times and was the most common answer.

# %%
def find_top_answers(df= data_df, ntop = 3):
  """ 
  Function that find the answers with the highest frequency given a data set

  Arguments:
    df -- df to evaluate
    ntop -- int with the number of top results to return

  Returns:
    results --  np with the results obtained
  """
  results = df.Answer.value_counts()[0:ntop]
  return results

# %%
df_king_question = return_df_with_certain_words_in_question(['King'])
results = find_top_answers(df_king_question, 5)
results
# Out:
# Henry VIII     41
# Sweden         24
# Solomon        23
# Norway         22
# Richard III    21
# Name: Answer, dtype: int64

# %% [markdown]
# 6. Explore from here! This is an incredibly rich dataset, and there are so many interesting things to discover. There are a few columns that we haven't even started looking at yet. Here are some ideas on ways to continue working with this data:
#
#  * Investigate the ways in which questions change over time by filtering by the date. How many questions from the 90s use the word `"Computer"` compared to questions from the 2000s?
#  * Is there a connection between the round and the category? Are you more likely to find certain categories, like `"Literature"` in Single Jeopardy or Double Jeopardy?
#  * Build a system to quiz yourself. Grab random questions, and use the <a href="https://docs.python.org/3/library/functions.html#input">input</a> function to get a response from the user. Check to see if that response was right or wrong.

# %% [markdown]
# a.    Investigate the ways in which questions change over time by filtering by the date. How many questions from the 90s use the word `"Computer"` compared to questions from the 2000s?

# %%
data_df['Air Date'] = pd.to_datetime(data_df['Air Date'], format='%Y-%m-%d')
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216930 entries, 0 to 216929
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Show Number  216930 non-null  int64
#  1   Air Date     216930 non-null  datetime64[ns]
#  2   Round        216930 non-null  object
#  3   Category     216930 non-null  object
#  4   Value        216930 non-null  object
#  5   Question     216930 non-null  object
#  6   Answer       216928 non-null  object
#  7   Value_float  213296 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 13.2+ MB

# %%
def return_df_with_certain_words_in_question_filtering_df(words_to_look, df = data_df):
  """ 
  Function that returns a dataframe where the column Question has a word passed as parameters. It has been considered caipatl letters

  Arguments:
    words_to_look -- List with the words to look

  Returns:
    df_result --  df with the rows containing any of the words passed in the list
  """
  df_result = pd.DataFrame()
  for index, row in df.iterrows():
    if any(word.lower() in row['Question'].lower().split() for word in words_to_look):
      df_result = pd.concat([df_result, row], axis = 1)
  df_result = df_result.T
  return df_result

# %%
df_before_00s = data_df.loc[(data_df['Air Date'] > '1988-12-31') & (data_df['Air Date'] < '1999-12-31')]
df_after_00s = data_df[(data_df['Air Date'] > '2000-01-01') & (data_df['Air Date'] < '2013-01-01')]

def compare_decades(words_to_investigate):
  """ 
  Function that compares the frequency of certains words in the questions befiore 00's and after 00's

  Arguments:
    words_to_investigate -- List with the words to look

  Print:
    The final comparison made with their corresponding result
  """
  results_before_00s = return_df_with_certain_words_in_question_filtering_df(words_to_investigate, df_before_00s).shape[0]
  results_after_00s = return_df_with_certain_words_in_question_filtering_df(words_to_investigate, df_after_00s).shape[0]
  print(f'The number of time the words {words_to_investigate} appeared before 00\'s were {results_before_00s} and after 00\'s were {results_after_00s}')

# %%
compare_decades(['facebook'])
# Out:
# The number of time the words ['facebook'] appeared before 00's were 0 and after 00's were 5

# %% [markdown]
# b. Is there a connection between the round and the category? Are you more likely to find certain categories, like "Literature" in Single Jeopardy or Double Jeopardy?

# %%
dict_categories = {}
for round in types_rounds:
  dict_categories[round] = data_df[data_df['Round'] == round].groupby(by='Category').count().sort_values(by=['Show Number'], ascending=False).iloc[:5,1]

# %%
dict_categories
# Out:
# {'Jeopardy!': Category
#  POTPOURRI           255
#  STUPID ANSWERS      255
#  SPORTS              253
#  ANIMALS             233
#  AMERICAN HISTORY    227
#  Name: Air Date, dtype: int64, 'Double Jeopardy!': Category
#  BEFORE & AFTER     450
#  LITERATURE         381
#  SCIENCE            296
#  WORLD GEOGRAPHY    254
#  OPERA              250
#  Name: Air Date, dtype: int64, 'Final Jeopardy!': Category
#  U.S. PRESIDENTS    50
#  WORD ORIGINS       34
#  STATE CAPITALS     31
#  AUTHORS            27
#  WORLD LEADERS      26
#  Name: Air Date, dtype: int64, 'Tiebreaker': Category
#  CHILD'S PLAY               1
#  LITERARY CHARACTERS        1
#  THE AMERICAN REVOLUTION    1
#  Name: Air Date, dtype: int64}

# %% [markdown]
# c.  Build a system to quiz yourself. Grab random questions, and use the <a href="https://docs.python.org/3/library/functions.html#input">input</a> function to get a response from the user. Check to see if that response was right or wrong.

# %%
def play_random_number (difficulty = 'Easy'):
  """ 
  Function used for selecting a random question and checking if the anser of the player was correct.

  Arguments:
    difficulty -- The difficulty type of the question. If the difficulty is Easy, the type of round is Jeopardy!

  """
  df = data_df[data_df['Round'] == 'Jeopardy!'] if difficulty == 'Easy' else data_df
  question_number = np.random.randint(low=0, high=df.shape[0])
  question = df.iloc[question_number,:]['Question']
  print(question)
  player_answer = input('Your answer:' )
  correct_answer = df.iloc[question_number,:]['Answer']
  if (player_answer.lower() == correct_answer.lower()):
    print('That\'s correct!!!')
  else:
    print('Sorry, wrong answer!!!')
    print('The right answer was ' + correct_answer)
